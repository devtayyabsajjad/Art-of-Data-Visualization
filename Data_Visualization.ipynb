# %% [markdown]
# <a href="https://colab.research.google.com/github/devtayyabsajjad/Art-of-Data-Visualization/blob/main/Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📊 The Art of Data Visualization: Exploring Matplotlib, Pyplot, and Seaborn
#
# In this notebook, you will **learn and understand** how to use **Matplotlib**, **Seaborn**, and **Plotly** to create **graphs** and **charts**. It will guide you through the **basics** of data visualization, helping you start your journey from **scratch**. You will also explore the **key differences** between these three powerful libraries and understand **when** and **why** to use each one.
#
# This notebook is designed for **beginners**, so no prior experience is required - let's begin your **data visualization journey**! 🚀

# %% [markdown]
# ![The Art of Data Visualization](https://cdn.leonardo.ai/users/b4c44e11-8cc9-4c47-b084-cded305deb9e/generations/a53aa0dc-3f15-4c56-8273-4844e30615ba/Leonardo_Phoenix_10_An_elegant_and_modern_digital_artwork_repr_1.jpg)

# %% [markdown]
# ---

# %% [markdown]
# # Table of Contents

# %% [markdown]
# ## 1. Introduction
#
# - 1.1 Overview of Python Data Visualization Tools
#   - 1.1.1 matplotlib
#   - 1.1.2 pyplot
#   - 1.1.3 seaborn
#   - 1.1.4 Plotly
#
# ## 2. Types of Data
#
# - 2.1 Quantitative Data
#   - 2.1.1 Continuous Data
#   - 2.1.2 Discrete Data
# - 2.2 Qualitative Data
#   - 2.2.1 Nominal Data
#   - 2.2.2 Ordinal Data
#
# ## 3. Import Matplotlib
#
# ## 4. Displaying Plots in Matplotlib
#
# - 4.1 Viewing Plots in Different Contexts
# - 4.2 Summary: Displaying Plots in Different Contexts
#
# ## 5. Matplotlib Object Hierarchy
# - 5.1 Main Objects in Matplotlib
# -- Figure
# -- Axes
# -- Axis
# -- Other Elements
#
# ## 6. Matplotlib Interfaces
#
# - 6.1 Pyplot API
# - 6.2 Object-Oriented API
#
# ## 7. Figure and Subplots
# - 7.1 What is a Figure?
# - 7.2 What is a Subplot?
#
# ## 8. First Plot with Matplotlib
#
# ## 9. Saving the Plot
#
# ## 10. Plot Types:
#
# - 10.1 Line Plot
# - 10.2 Scatter Plot
# - 10.3 Histogram
# - 10.4 Bar Chart
# - 10.5 Horizontal Bar Chart
# - 10.6 Error Bar Chart
# - 10.7 Stacked Bar Chart
# - 10.8 Pie Chart
# - 10.9 Box Plot
# - 10.10 Area Chart
# - 10.11 Contour Plot
#
# ## 11. Styles with Matplotlib Plots
#
# ## 12. Adding a Grid
#
# ## 13. Handling Axes
#
# ## 14. Handling X and Y Ticks
#
# ## 15. Adding Labels
#
# ## 16. Adding a Title
#
# ## 17. Adding a Legend
#
# ## 18. Control Colours
#
# ## 19. Control Line Styles
#
# ## 20. Seaborn
#
# ## 21. Plotly
#
# ## 22. Summary: Data Visualization in Python

# %% [markdown]
# ---

# %% [markdown]
# # Data Visualization

# %% [markdown]
# Data visualization is the process of showing information using charts, graphs, and tables.  This helps us analyze and understand data clearly, making it easier to make decisions.

# %% [markdown]
# # 1. Introdunction

# %% [markdown]
# ## 1.1 Overview of Python Data Visualization Tools
#
# Python has three main tools for **drawing graphs and charts**:
#
# ### 1.1.1 matplotlib
#
# - **Matplotlib** is a popular Python library for creating **graphs and charts**.
# - It is used to draw **line plots**, **bar charts**, **scatter plots**, **histograms**, and more.
# - It is **flexible** and allows for **customizing** every part of a plot.
# - **Seaborn** includes a **collection of sample datasets** for quick testing and learning.
# - **Example:** It is best for making **simple** and **detailed** visualizations.
#
# ### 1.1.2 pyplot (Module of Matplotlib)
#
# - **Pyplot** is a **module** of **Matplotlib** that provides an **easy** way to create plots.
# - It works like **MATLAB**, allowing you to make plots using **simple commands**.
# - It automatically handles **figure creation**, **axes**, and **plotting**.
# - **Example:** Use `plt.plot()` to quickly create **line graphs** and other basic charts.
#
#
# ### 1.1.3 seaborn
#
# - **Seaborn** is a Python library built on **Matplotlib** for creating **attractive** and **informative** statistical graphs.
# - It provides **better styling** and **simpler syntax** for complex visualizations.
# - While Seaborn graphs are **not fully interactive**, they are **highly customizable** and work well for **data analysis**.
# - **Example:** Use Seaborn for **heatmaps**, **box plots**, **violin plots**, and **pair plots**.
#
#
# ### 1.1.4 Plotly
# - **Plotly** is a **Python library** for creating **interactive** and **high-quality** visualizations.
# - It supports a wide range of **charts** like **line charts**, **scatter plots**, **bar charts**, **3D plots**, and **maps**.
# - **Interactive features** like **zooming**, **hovering**, and **panning** make it ideal for **exploratory data analysis**.
# - **Highly customizable** with options for **themes**, **colors**, **axes**, and **annotations**.
#
# ---

# %% [markdown]
# ### 📊 **Summary: Differences Between Matplotlib, Seaborn, and Plotly**
#
# | **Feature**           | **Matplotlib**                             | **Seaborn**                                | **Plotly**                                 |
# |-----------------------|--------------------------------------------|--------------------------------------------|---------------------------------------------|
# | **Definition**        | A basic Python library for **static** plots. | Built on Matplotlib for **statistical** plots. | Interactive visualization library for **dynamic** charts. |
# | **Interactivity**     | **No** (Static images).                     | **No** (Static images).                     | **Yes** (Interactive – hover, zoom, pan).    |
# | **Ease of Use**       | **Moderate** – Requires manual customization.| **Easier** – Simple syntax for complex visuals.| **User-friendly** – Easy for quick interactive graphs. |
# | **Customization**    | **High** – Full control over every element.  | **Moderate** – Customizable but limited to styles.| **High** – Extensive customization and interactivity. |
# | **Best For**         | **Basic** plots and full **custom control**.  | **Statistical** data (e.g., heatmaps, box plots). | **Interactive** dashboards and advanced analytics. |
# | **Common Plot Types** | Line, Bar, Scatter, Histogram.               | Heatmaps, Violin, Box, Pair Plots.          | Line, Scatter, 3D Surface, Pie, Maps.       |
# | **Performance**      | **Fast** for simple plots.                    | **Efficient** for statistical visualization. | **Slower** for large datasets (due to interactivity). |
# | **Output Format**    | PNG, PDF, SVG (static images).                | PNG, PDF, SVG (static images).               | HTML, PNG, JPEG (interactive and static).   |
# | **When to Use**      | **Basic visualizations** and publication-quality charts. | **Quick** and **beautiful** statistical visualizations. | **Interactive** visualizations for web apps and dashboards. |
# | **Example Use Case** | **Scientific** reports, publications.          | **Statistical** analysis, **data exploration**. | **Interactive dashboards**, web applications. |

# %% [markdown]
# # 2. Types of Data

# %% [markdown]
# Data is divided into two main categories: **Quantitative Data** (numerical) and **Qualitative Data** (categorical). Each type provides different kinds of information and serves specific analytical purposes.
#
# ---
#
# ## 2.1 Quantitative Data
#
# **Quantitative data** represents **numerical** values that can be **measured** or **counted**. It answers questions like **"How much?"** or **"How many?"**
#
# ### 🔢 **Types of Quantitative Data:**
# 1. **Continuous Data**
# 2. **Discrete Data**
#
#
#
# ### 2.1.1 Continuous Data
#
# - **Definition:** Continuous data can take **any value** within a range, including **decimals** or **fractions**.
# - It is **measurable** and represents information that can have an **infinite** number of values.
#
# - **Examples:**
#   - Height: 5.8 feet
#   - Weight: 70.5 kg
#   - Temperature: 36.7°C
#   - Time: 3.45 hours
#
# **When to Use:**
# Use continuous data when values can take **infinite** possibilities within a given range.
#
#
#
# ### 2.1.2 Discrete Data
#
# - **Definition:** Discrete data includes **fixed**, **countable** values that cannot be **broken down** into smaller parts.
# - It represents **whole numbers** or **specific counts**.
#
# - **Examples:**
#   - Number of students in a class: 30
#   - Cars in a parking lot: 12
#   - Test scores: 95
#   - Number of pets: 3
#
# **When to Use:**
# Use discrete data when the data consists of **separate**, **whole values** that cannot be subdivided.
#
# ---
#
# ## 2.2 Qualitative Data
#
# **Qualitative data** (or **categorical** data) describes **categories** or **labels** rather than numbers. It answers questions like **"What kind?"** or **"Which category?"**
#
# ### 🔢 **Types of Qualitative Data:**
# 1. **Nominal Data**
# 2. **Ordinal Data**
#
# ---
#
# ### 2.2.1 Nominal Data
#
# - **Definition:** Nominal data represents **categories** or **labels** without any **natural order** or ranking.
# - It is **descriptive** and cannot be arranged in a logical sequence.
#
# - **Examples:**
#   - Gender: Male, Female
#   - Colors: Red, Blue, Green
#   - Blood Group: A, B, AB, O
#   - Types of Fruit: Apple, Banana, Mango
#
# **When to Use:**
# Use nominal data when the categories are **distinct** and **cannot** be logically ordered.
#
#
#
# ### 2.2.2 Ordinal Data
#
# - **Definition:** Ordinal data represents **categories** with a **specific order** or ranking.
# - The order is **meaningful**, but the **difference** between categories is **not precisely defined**.
#
# - **Examples:**
#   - Education Level: High School, Bachelor, Master, PhD
#   - Customer Satisfaction: Poor, Fair, Good, Excellent
#   - Clothing Size: Small, Medium, Large, Extra Large
#   - Pain Level: Mild, Moderate, Severe
#
# **When to Use:**
# Use ordinal data when the **order** of the categories **matters**, but the **exact difference** is not measurable.
#
# ---
#
# ## 📊 **Summary Table: Types of Data**
#
# | **Category**        | **Type**            | **Definition**                          | **Examples**                             |
# |---------------------|---------------------|-----------------------------------------|------------------------------------------|
# | **Quantitative**    | **Continuous**      | Data that can take **any value**.       | Height (5.8 ft), Temperature (36.7°C).  |
# | **Quantitative**    | **Discrete**        | Data that consists of **fixed values**. | Number of students (30), Cars (12).     |
# | **Qualitative**     | **Nominal**         | **Labels** with **no natural order**.   | Gender (Male/Female), Colors (Blue).    |
# | **Qualitative**     | **Ordinal**         | **Ordered** categories with **ranking**.| Education Level (Bachelor, Master).     |
#
# ---

# %% [markdown]
# ## 3. Import Matplotlib

# %% [markdown]
# To use **Matplotlib** in Python, you need to **import** it first. The most commonly used module is **pyplot**, which allows you to create various plots easily.
#
# ---
#
# ### ✅ Basic Import Statement
#
# ```python
# import matplotlib.pyplot as plt

# %% [markdown]
# # 4. Displaying Plots in Matplotlib

# %% [markdown]
# # 4. Displaying Plots in Matplotlib
#
# **Matplotlib** allows you to display plots in **different environments** based on how and where you're running the code. The way you display plots depends on whether you're working in a **Python script**, **IPython shell**, or **Jupyter notebook**.
#
# ---
#
# ## 4.1 Viewing Plots in Different Contexts
#
# There are **three main ways** to display plots in Matplotlib:
#
# 1. **From a Python Script**
# 2. **From an IPython Shell**
# 3. **From a Jupyter Notebook**
#
# ---
#
# ## 4.2 Summary: Displaying Plots in Different Contexts
#
# | **Context**         | **Command to Use**            | **Plot Behavior**                      | **When to Use**                           |
# |---------------------|-------------------------------|----------------------------------------|--------------------------------------------|
# | **Python Script**   | `plt.show()`                  | Opens a **new window** for the plot.   | For **standalone Python programs** (.py files). |
# | **IPython Shell**   | `%matplotlib` (optional)      | Interactive by default with `plt.show()` | For **interactive terminals** like IPython or **IDLE**. |
# | **Jupyter Notebook**| `%matplotlib inline`          | **Static** image inside the notebook.  | When working in **Jupyter Notebooks** and you want **simple** plots. |
# | **Interactive Plot**| `%matplotlib notebook`        | **Zoomable** and **interactive** plot. | For **interactive** plots (with zoom/pan features) in **Jupyter Notebooks**. |
#
# ---

# %% [markdown]
# 5. Matplotlib Object Hierarchy

# %% [markdown]
# In **Matplotlib**, a plot is made up of different **objects**. These objects are like building blocks that help you create and customize your plot.
#
# At the **top** is the **Figure** (the entire plot area), and inside it, there are **Axes**, **Axis**, and other parts like **tick marks**, **lines**, **legends**, **titles**, and **text boxes**.
#
# ---
#
# ## 5.1 Main Objects in Matplotlib
#
# 1. **Figure** – The **whole** plot area (can hold one or more plots).
# 2. **Axes** – The **individual plot** inside the figure.
# 3. **Axis** – The **X-axis** and **Y-axis** in a plot.
# 4. **Other Elements** – Extra parts inside the plot:
#    - **Tick Marks** – Small lines on the axis to show **scale**.
#    - **Lines** – Curves or markers to **show data**.
#    - **Legend** – Explains what each **line** or **marker** means.
#    - **Title** – The **heading** of the plot.
#    - **Text Boxes** – Custom **labels** or **annotations**.
#
# ---

# %% [markdown]
# ## Example

# %%
import matplotlib.pyplot as plt

# Data for the plot
x = [1, 2, 3, 4, 5]
y1 = [10, 20, 25, 30, 35]
y2 = [15, 25, 30, 35, 40]

# Create a figure and axes
fig, ax = plt.subplots()

# Plotting two lines
ax.plot(x, y1, label="Line 1", color="blue", linestyle="--", marker="o")  # Line 1
ax.plot(x, y2, label="Line 2", color="green", linestyle="-", marker="s")  # Line 2

# Add parts of the plot
ax.set_title("Parts of a Plot Example")      # Title
ax.set_xlabel("X-axis (Time)")               # X-axis label
ax.set_ylabel("Y-axis (Value)")              # Y-axis label
ax.legend()                                  # Legend
ax.grid(True)                                # Grid
ax.set_xticks([1, 2, 3, 4, 5])               # Custom tick marks on X-axis
ax.set_yticks([10, 20, 30, 40])              # Custom tick marks on Y-axis
ax.text(3, 28, "Important Point", color="red") # Annotation (text box)

# Display the plot
plt.show()

# %% [markdown]
# # 6. Matplotlib Interfaces

# %% [markdown]
# ## 📊 Pyplot API vs. Object-Oriented API
#
# | **Feature**          | **Pyplot API**                | **Object-Oriented API**           |
# |----------------------|-------------------------------|-----------------------------------|
# | **Definition**       | Simple way to create plots.   | Advanced way to create plots.     |
# | **Ease of Use**      | **Easy** and beginner-friendly. | **More control**, slightly harder.|
# | **Best For**         | **Simple** and **quick** plots. | **Complex** and **custom** plots. |
# | **Method Style**     | Uses **functions** (e.g., `plt.plot()`). | Uses **methods** (e.g., `ax.plot()`). |
# | **Multiple Plots**   | **Hard** to handle.            | **Easy** to manage.               |
# | **Customization**    | **Limited** customization.     | **Full** customization.           |
# | **Use Case**         | **Basic** graphs.              | **Advanced** and **multi-plot** graphs. |
#
# ---
#
#  **When to Use:**
# - **Pyplot API** – For **simple** and **quick** plots.
# - **Object-Oriented API** – For **advanced** plots requiring more **control** and **customization**.

# %% [markdown]
# # 7. Figure and Subplots

# %% [markdown]
# ##  7.1 What is a Figure?
#
# - A **Figure** is the **main container** that holds one or more plots.
# - It acts like a **canvas** where you draw your plots.
# - You can create a **blank figure** using `plt.figure()`.
#
#
# ##  7.2 What is a Subplot?
#
# - A **Subplot** is an **individual plot** inside a **figure**.
# - You can create one or **multiple** subplots using:
#   - **`plt.subplot()`** – For **manual** subplot creation.
#   - **`plt.subplots()`** – For **automatic** subplot creation.
#
# ---

# %% [markdown]
# # 8. First Plot with Matplotlib

# %% [markdown]
# - **Step 1:** Import **Matplotlib** using `import matplotlib.pyplot as plt`.
# - **Step 2:** Use `plt.plot()` to **draw** a line.
# - **Step 3:** Use `plt.show()` to **display** the plot.

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [10, 20, 30, 40]

# Custom line style
plt.plot(x, y, color='red', linestyle='--', marker='o')

plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Customized Plot")

plt.show()

# %% [markdown]
# # 9. Saving the Plot

# %% [markdown]
# You can **save** Matplotlib plots as **image files** in different formats (e.g., **PNG**, **JPG**, **PDF**). This is useful when you want to **share** or **store** your visualizations.
#
# ---
#
# ## Basic Syntax for Saving a Plot
#
# ```python
# plt.savefig("filename.format")

# %% [markdown]
# # 10. Plot Types in Matplotlib

# %% [markdown]
# ## 10.1 Line Plot
#
# - **Purpose:** Used to show **trends** and **changes** over time.
# - **Best For:** Visualizing **continuous** data.

# %% [markdown]
# ### Example for Line Plot

# %%
import matplotlib.pyplot as plt

# Data
x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 35]

# Line plot
plt.plot(x, y, marker='o', linestyle='-', color='blue')

plt.title("Line Plot Example")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

plt.show()

# %% [markdown]
# ## 10.2 Scatter Plot
# - Purpose: Displays individual points to show relationships between variables.
# - Best For: Identifying patterns, clusters, and outliers.

# %% [markdown]
# ### Example for Scatter Plot

# %%
import matplotlib.pyplot as plt

# Data
x = [5, 7, 8, 10, 12]
y = [15, 18, 22, 30, 40]

# Scatter plot
plt.scatter(x, y, color='red', marker='x')

plt.title("Scatter Plot Example")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

plt.show()

# %% [markdown]
# ## 10.3 Histogram
# - Purpose: Shows the distribution of numerical data.
# - Best For: Analyzing frequency or data ranges.

# %% [markdown]
# ### Example for Histogram

# %%
import matplotlib.pyplot as plt

# Data
data = [10, 15, 20, 25, 30, 35, 40, 30, 25, 20]

# Histogram
plt.hist(data, bins=5, color='green', edgecolor='black')

plt.title("Histogram Example")
plt.xlabel("Values")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# ## 10.4 Bar Chart
# - Purpose: Represents categories with rectangular bars.
# - Best For: Comparing discrete data or categories.

# %% [markdown]
# ### Example for Bar Chart

# %%
import matplotlib.pyplot as plt

# Data
categories = ['A', 'B', 'C', 'D']
values = [10, 25, 30, 45]

# Bar chart
plt.bar(categories, values, color='purple')

plt.title("Bar Chart Example")
plt.xlabel("Categories")
plt.ylabel("Values")

plt.show()

# %% [markdown]
# ## 10.5 Horizontal Bar Chart
# - Purpose: Similar to a bar chart, but horizontal.
# - Best For: Comparing categories with long labels.

# %% [markdown]
# ### Example for Horizontal bar Chart

# %%
import matplotlib.pyplot as plt

# Data
categories = ['A', 'B', 'C', 'D']
values = [10, 25, 30, 45]

# Horizontal bar chart
plt.barh(categories, values, color='orange')

plt.title("Horizontal Bar Chart Example")
plt.xlabel("Values")
plt.ylabel("Categories")

plt.show()

# %% [markdown]
# ## 10.6 Error Bar Chart
# - Purpose: Shows variability or uncertainty in the data.
# - Best For: Visualizing error margins or confidence intervals.

# %% [markdown]
# ### Example for Error Bar Chart

# %%
import matplotlib.pyplot as plt

# Data
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]
errors = [1, 2, 1, 3]

# Error bar chart
plt.errorbar(x, y, yerr=errors, fmt='o', color='blue')

plt.title("Error Bar Chart Example")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

plt.show()

# %% [markdown]
# ## 10.7 Stacked Bar Chart
# - Purpose: Displays multiple datasets on top of each other.
# - Best For: Comparing the contribution of parts to a whole.

# %% [markdown]
# ### Example for Stacked Bar Chart

# %%
import matplotlib.pyplot as plt

# Data
categories = ['A', 'B', 'C']
group1 = [5, 10, 15]
group2 = [3, 7, 9]

# Stacked bar chart
plt.bar(categories, group1, color='cyan', label='Group 1')
plt.bar(categories, group2, bottom=group1, color='magenta', label='Group 2')

plt.title("Stacked Bar Chart Example")
plt.xlabel("Categories")
plt.ylabel("Values")
plt.legend()

plt.show()

# %% [markdown]
# ## 10.8 Pie Chart
# A **pie chart** is used to show **proportions** or **percentages** of different categories in a **circular format**.

# %% [markdown]
# ### Example for Pie Chart

# %%
import matplotlib.pyplot as plt

# Data
sizes = [40, 30, 20, 10]
labels = ['A', 'B', 'C', 'D']

# Pie chart
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)

# Add title
plt.title("Pie Chart Example")

# Display the
# Out:
# Text(0.5, 1.0, 'Pie Chart Example')

# %% [markdown]
# ## 10.9 Box plot
# A **box plot** (or **box-and-whisker plot**) is used to display the **spread** and **distribution** of a dataset, including **median**, **quartiles**, and **outliers**.

# %% [markdown]
# ### Example for Box Plot

# %%
import matplotlib.pyplot as plt

# Data
data = [7, 15, 36, 39, 44, 45, 50, 62, 70, 95]

# Box plot
plt.boxplot(data)

# Add title
plt.title("Box Plot Example")

# Display the plot
plt.show()

# %% [markdown]
# ## 10.10 Area Chart
#
# An **area chart** is a **filled line plot** that shows **cumulative data** over time or a continuous range.

# %% [markdown]
# ### Example for Area Chart

# %%
import matplotlib.pyplot as plt

# Data
x = [1, 2, 3, 4, 5]
y = [10, 20, 30, 40, 50]

# Area chart
plt.fill_between(x, y, color='skyblue', alpha=0.7)

# Add title and labels
plt.title("Area Chart Example")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

# Display the plot
plt.show()

# %% [markdown]
# # 10.11 Contour Plot
# A **contour plot** is used to **visualize 3D data** in a **2D** format by drawing **contours** (lines of equal value).

# %% [markdown]
# ### Example for Counter Plot

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x = np.linspace(0, 5, 50)  # X-axis range
y = np.linspace(0, 5, 40)  # Y-axis range
X, Y = np.meshgrid(x, y)   # Create grid
Z = np.sin(X) * np.cos(Y)  # Z values (height)

# Contour plot
plt.contour(X, Y, Z, cmap='viridis')

# Add title and labels
plt.title("Contour Plot Example")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

# Display the plot
plt.show()

# %% [markdown]
# ## 11. Styles with Matplotlib Plots
# Matplotlib allows you to **customize** the appearance of your plots using **styles**. You can choose from **predefined styles** or create your **own style** for a better visual presentation.
#
# ---
#
# ### Viewing Available Styles
#
# You can check all the **available styles** using:
#
# ```python
# import matplotlib.pyplot as plt
#
# # List available styles
# print(plt.style.available)

# %% [markdown]
# ### Example

# %%
import matplotlib.pyplot as plt

# Custom settings
plt.rcParams['axes.facecolor'] = 'lightgray'  # Background color
plt.rcParams['lines.linestyle'] = '--'        # Dashed lines
plt.rcParams['axes.titlesize'] = 18           # Title size

# Data
x = [1, 2, 3, 4]
y = [10, 20, 30, 40]

# Custom styled plot
plt.plot(x, y, color='darkblue', marker='s')
plt.title("Custom Styled Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

plt.show()

# %% [markdown]
# ## Adding a Grid
# A **grid** adds **reference lines** to the plot, making it easier to read and compare values.

# %% [markdown]
# ### Example

# %%
import matplotlib.pyplot as plt

# Data
x = [1, 2, 3, 4]
y = [10, 20, 30, 40]

# Create plot
plt.plot(x, y)

# Add a grid
plt.grid(True)

plt.title("Grid Example")
plt.show()

# %% [markdown]
# # 13. Handling Axes
# You can **set**, **limit**, and **customize** the **X-axis** and **Y-axis** in Matplotlib.

# %% [markdown]
# ### Example

# %%
import matplotlib.pyplot as plt

# Data
x = [1, 2, 3]
y = [10, 20, 30]

plt.plot(x, y)

# Set axis limits
plt.xlim(0, 5)  # X-axis range
plt.ylim(0, 50) # Y-axis range

plt.title("Axis Example")
plt.show()

# %% [markdown]
# ## 14. Handling X and Y Ticks
# **Ticks** are **scale markers** on the **X-axis** and **Y-axis**.

# %% [markdown]
# ### Example

# %%
import matplotlib.pyplot as plt

# Data
x = [1, 2, 3]
y = [10, 20, 30]

plt.plot(x, y)

# Custom tick marks
plt.xticks([0, 1, 2, 3, 4])
plt.yticks([0, 10, 20, 30, 40])

plt.title("Custom Ticks")
plt.show()

# %% [markdown]
# ## 15. Adding Labels
# **Labels** describe what the **X-axis** and **Y-axis** represent.

# %% [markdown]
# ### Example

# %%
import matplotlib.pyplot as plt

# Data
x = [1, 2, 3]
y = [10, 20, 30]

plt.plot(x, y)

# Add labels
plt.xlabel("X-axis (Time)")
plt.ylabel("Y-axis (Values)")

plt.title("Axis Labels Example")
plt.show()

# %% [markdown]
# ## 16. Adding a Title
#
# A **title** provides a brief **description** of the plot.

# %% [markdown]
# ### Example

# %%
import matplotlib.pyplot as plt

# Data
x = [1, 2, 3]
y = [10, 20, 30]

plt.plot(x, y)

# Add a title
plt.title("My First Plot")

plt.show()

# %% [markdown]
# ## 17. Adding a Legend
# A **legend** explains the meaning of **lines** or **markers** in the plot.

# %% [markdown]
# ### Example

# %%
import matplotlib.pyplot as plt

# Data
x = [1, 2, 3]
y1 = [10, 20, 30]
y2 = [30, 20, 10]

plt.plot(x, y1, label="Line 1")
plt.plot(x, y2, label="Line 2")

# Add a legend
plt.legend()

plt.title("Legend Example")
plt.show()

# %% [markdown]
# ## 18. Control Colours
# You can customize the **colors** of lines, markers, and areas.

# %% [markdown]
# ### Example

# %%
import matplotlib.pyplot as plt

# Data
x = [1, 2, 3]
y = [10, 20, 30]

# Change color
plt.plot(x, y, color='red')

plt.title("Custom Color Example")
plt.show()

# %% [markdown]
# ## 19. Control Line Styles
# Line styles define **how lines** in your plot appear (solid, dashed, etc.).

# %% [markdown]
# ### Example

# %%
import matplotlib.pyplot as plt

# Data
x = [1, 2, 3]
y = [10, 20, 30]

# Custom line styles
plt.plot(x, y, linestyle='--', color='blue', marker='o')

plt.title("Line Style Example")
plt.show()

# %% [markdown]
# ## 20. **Seaborn**

# %% [markdown]
# - Built on **Matplotlib** for **better aesthetics** and **simplified** plotting.
# - Ideal for **statistical** analysis and works well with **DataFrames**.
# - Supports built-in **datasets** for quick testing.
#
# ### Installing Seaborn (if not installed):
#
# ```bash
# pip install seaborn

# %% [markdown]
# ### Example

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load Sample Dataset
tips = sns.load_dataset('tips')

# Create a Box Plot
sns.boxplot(x='day', y='total_bill', data=tips)

plt.title("Seaborn Box Plot Example")
plt.show()

# %% [markdown]
# ## 21. **Plotly**

# %% [markdown]
# - Provides **interactive** visualizations with **zoom**, **hover**, and **pan**.
# - Useful for **web applications** and **dashboards**.
# - Supports a wide range of 2D and **3D** charts.
#
# ### Installing Plotly (if not installed):
#
# ```bash
# pip install plotly

# %% [markdown]
# ### Example

# %%
import plotly.graph_objects as go

# Create a Line Chart
fig = go.Figure(data=go.Scatter(x=[1, 2, 3], y=[10, 15, 13], mode='lines+markers'))
fig.update_layout(title="Plotly Line Chart Example")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 📌 **Note: Exploring Data Visualization Libraries**
#
# In this notebook, we have **explored Matplotlib** in detail, covering its core functionalities for creating **basic** and **customizable** plots. Additionally, we provided an **overview** of **Seaborn** and **Plotly**, highlighting their unique features and differences.
#
# This notebook gives a clear understanding of **when to use** each library based on **visualization needs**, whether you want static plots, statistical insights, or interactive data exploration.

# %% [markdown]
# ## 22. **Summary: Data Visualization in Python**

# %% [markdown]
# This notebook provides a comprehensive guide to **data visualization** using three powerful Python libraries: **Matplotlib**, **Seaborn**, and **Plotly**. Each library offers unique strengths for creating clear and effective visualizations.
#
# - **Matplotlib** is ideal for **basic** and **customizable** static plots, providing full control over every plot element.
# - **Seaborn** builds on Matplotlib, offering **beautiful** and **statistical** visualizations with simpler syntax and built-in datasets for quick analysis.
# - **Plotly** excels in **interactive** and **dynamic** visualizations, making it perfect for **web-based** applications and **exploratory** data analysis.
#
# This notebook covers the **key differences**, **best use cases**, and **practical examples** for each library, enabling you to choose the right tool based on your visualization needs. Whether you want to create simple charts, advanced statistical plots, or fully interactive dashboards, this guide equips you with the essential skills for effective data storytelling.

# %% [markdown]
# ---
#
# ## 🙌 **Thank You!**
#
# Thank you for exploring **The Art of Data Visualization** with **Matplotlib**, **Seaborn**, and **Plotly**! 🎉
#
# We hope this notebook helped you understand the basics and differences between these powerful visualization libraries.
#
# Feel free to **experiment**, **customize**, and **explore** more as you continue your **data visualization journey**.
#
# **Happy coding, and keep visualizing! 🚀**
